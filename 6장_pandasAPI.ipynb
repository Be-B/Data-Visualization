# %% [markdown]
# <a href="https://colab.research.google.com/github/Be-B/Data-Visualization/blob/main/6%EC%9E%A5_pandasAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### API 활용해서 데이터 분석하기
#
# - 데이터 => titanic
# - API => Openapi 활용

# %%
import seaborn as sns

# 데이터 로드
titanic = sns.load_dataset('titanic')
titanic.head(5)

# %% [markdown]
# # PandasAI
#
# - https://pandas-ai.com/

# %%
# 환경 변수 설정
os.environ['OPENAI_API_KEY'] = 'API_KEY'

# %%
# !pip install pandasai

# %%
import os
from dotenv import load_dotenv
from google.colab import drive

drive.mount('/content/drive')

# .env 파일 경로 지정
dotenv_path = '/content/drive/MyDrive/05.Colab_Notebooks/.env'
load_dotenv(dotenv_path=dotenv_path)

# 환경 변수 사용
api_key = os.getenv('OPENAI_API_KEY')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(api_key)
# Out:
# None

# %%
# Loading the API token to OpenAI environment
llmodel = OpenAI(api_token='API_KEY')

# Initializing an instance of PandasAI with OpenAI environment
sdf = SmartDataframe(titanic, config={"llm": llmodel})

# %%
#Create the prompt variable
First_prompt = "각 클래스별 man, woman, child를 구분해서 탑승인원을 sns.countplot를 사용하고 palette는 Reds를 사용해서 그려줘"

#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(First_prompt)
# Out:
# '/content/exports/charts/temp_chart.png'
